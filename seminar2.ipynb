# %%
num = int(input('Enter a number: ')) #task1
print(num > 5)
# Out:
# True

# %%
num = int(input('Enter a number: ')) #task2

print(num % 2 == 0)
# Out:
# True

# %%
a, b = input('Enter two numbers: ').split() #task3
a = int(a)
b = int(b)

print(a == 2 * b)
# Out:
# True

# %%
#task4
num = int(input('Enter a number: '))

if (num % 3 == 0):
    print('Yes ')
else:
    print('No')
# Out:
# Yes

# %%
num = int(input('Enter a number: ')) #task5

if (num % 2 == 0):
    print(num)
else:
    print(num + 1)
# Out:
# 8

# %%
num = int(input('Enter a number: ')) #task6

if (num > 3 and num <= 8):
    print('Yes ')
else:
    print('No')
# Out:
# No

# %%
num = int(input('Enter a number: ')) #task7

if (num >= 5 and num < 15 and num != 10):
    print('Yes ')
else:
    print('No')
# Out:
# No

# %%
num = int(input('Enter a number: ')) #task8

if (num <= 5 or num > 10):
    print('Yes ')
else:
    print('No')
# Out:
# No

# %%
num = int(input('Enter a number: ')) #task9

if (2 < num <= 6 or x > 10):
    print('Yes ')
else:
    print('No')
# Out:
# No

# %%
x = int(input('Enter a number: ')) #task10

if ((x < 4 or x > 10) and (x <= 2 or x >= 6)):
    print('Yes ')
else:
    print('No')
# Out:
# Yes

# %%
x = int(input('Enter a number: ')) #task11

if ((x <= 3) or (x > 5)):
    print('Yes ')
else:
    print('No')
# Out:
# No

# %%
x = int(input('Enter a number: ')) #task12

if (-3 < x <= 6):
    print(f'x is in between -3  and 6 inclusively')
if (x >= 4):
    print(f'{x} is greater than or equal to 4')
if (-2 < x <= 3) or (5 < x):
    print(f'{x} is more than -2 but less than or equal to 3, or bigger than 5')
if (0 < x < 4) or (6 <= x < 10):
    print(f'{x} is more than 0 and less than 4, it  ould also be more than or equal to 6 but less than 10')
# Out:
# 78 is greater than or equal to 4
# 78 is more than -2 but less than or equal to 3, or bigger than 5

# %%
x = int(input('Введите угол входа: ')) #task13
if (40 <= x <= 45):
    print('"Параметры оптимальны"')
elif (x < 40):
    print("Корабль разрушится в атмосфере")
elif (x > 45):
    print("Контролируемый спуск невозможен")
# Out:
# Контролируемый спуск невозможен

# %%
x = float(input("Введите x точки: "))
y = float(input("Введите y точки: ")) #task14

if y  < (0.5 * x + 4) :
    print('Точка ниже прямой ')
elif y > (0.5 * x + 4) :
    print('Точка выше прямой ')
else :
    print('Точка находится на прямой ')
# Out:
# Точка находится на прямой
