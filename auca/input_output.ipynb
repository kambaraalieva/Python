# %%
a = 4
p = 4 * a
print(p)
# Out:
# 16

# %%
a = 7
s = a**2
print(s)
# Out:
# 49

# %%
a = 4
b = 5
square = a * b
p = 2 * (a + b)

print(f"Square is {square}, perimeter is {p}")
# Out:
# Square is 20, perimeter is 18

# %%
from math import pi
d = 10
l = pi * d
print(l)
# Out:
# 31.41592653589793

# %%
a = 3
v = a ** 3
s_cube = 6 * (a**2)
print(v, s_cube)
# Out:
# 27 54

# %%
a = 4
b = 2
c = 6
volume = a * b * c
surface_square = 2 * (a*b + b*c + a*c)
print(volume, surface_square)
# Out:
# 48 88

# %%
from math import pi
r = float(input("Write the radius: "))
l = 2 * pi * r
s = pi * (r**2)
print(l, s)
# Out:
# 18.84955592153876 28.274333882308138

# %%
a = 4
b = 2
mean = (a + b) / 2
print(mean)
# Out:
# 3.0

# %%
import math
a, b = map(int, input("Write two numbers: ").split())
a, b = abs(a), abs(b)

g_mean = math.sqrt(a * b)
print(g_mean)
# Out:
# 4.47213595499958

# %%
a = float(input("Enter a: "))
b = float(input("Enter b: "))

a2 = a ** 2
b2 = b ** 2

print("Sum:", a2 + b2)
print("Difference:", a2 - b2)
print("Product:", a2 * b2)
print("Quotient:", a2 / b2)
# Out:
# Sum: 13.0
# Difference: -5.0
# Product: 36.0
# Quotient: 0.4444444444444444

# %%
a = float(input("Enter a: "))
b = float(input("Enter b: "))

a2 = abs(a)
b2 = abs(b)

print("Sum:", a2 + b2)
print("Difference:", a2 - b2)
print("Product:", a2 * b2)
print("Quotient:", a2 / b2)
# Out:
# Sum: 9.0
# Difference: -1.0
# Product: 20.0
# Quotient: 0.8

# %%
import math
a, b = map(int, input("Enter two numbers: ").split())
a, b = abs(a), abs(b)

c = math.sqrt(a**2 + b**2)
p = a + b + c
print("Perimeter:", a + b + c)
print(c)
# Out:
# Perimeter: 12.0
# 5.0

# %%
R1 = float(input("Enter R1 (outer radius): "))
R2 = float(input("Enter R2 (inner radius): "))

pi = 3.14

S1 = pi * R1**2
S2 = pi * R2**2
S3 = S1 - S2

print("Area of outer circle S1:", S1)
print("Area of inner circle S2:", S2)
print("Area of the ring S3:", S3)
# Out:
# Area of outer circle S1: 78.5
# Area of inner circle S2: 12.56
# Area of the ring S3: 65.94

# %%
from math import pi
l = float(input("Enter length: "))
# l = pi * r * 2
r = l / 2 / pi
print(r)
s = (r**2) * pi
print(s)
# Out:
# 0.477464829275686
# 0.716197243913529

# %%
import math
s = float(input("Enter square: "))
# l = pi * r * 2
# s = r**2 * pi
r = math.sqrt(s / pi)
d = r * 2
print(d)
l = d * pi
print(l)
# Out:
# 3.385137501286538
# 10.634723105433096

# %%
import math
a, b = map(int, input("Enter two numbers: ").split())
distance = abs(b - a)
print(distance)
# Out:
# 1

# %%
a, b, c = map(int, input("Enter three numbers: ").split())
ac = abs(a - c)
bc = abs(b - c)
sum_ = ac + bc
print(sum_, ac, bc)
# Out:
# 3 2 1
