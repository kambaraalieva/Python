# %%
from random import randint
color_list = ['blue', 'red', 'green', 'yellow', 'cyan', 'magenta', 'cyan', 'magenta']
res_list = []
rand_color = [color_list[randint(0, 2)] for i in range(5)]
rand_color
# Out:
# ['blue', 'red', 'blue', 'blue', 'green']

# %%
def average(a, b, c):
    return a + b + c / 3
average(2, 3, 6)
# Out:
# 7.0

# %%
def describe_number(n):
    if n > 0:
        print('Positive')
    elif n < 0:
        print('Negative')
    else:
        print('Zero')

describe_number(-3)
# Out:
# Negative
