# %%
x = ['a', 'b', 'c', 'd']
x_0 = x.pop()
print(x_0)
# Out:
# d

# %%
x = ['a', 'b', 'c', 'd']
x.index('b', 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 x = ['a', 'b', 'c', 'd']
# ----> 2 x.index('b', 2)
#
# ValueError: 'b' is not in list

# %%
x = ['a', 'b', 'c', 'd']
del x[0]

# %%
x = ['a', 'b', 'c', 'd']
min(x), max(x), sum(x), len(x)

# %%
max((1, 2, 5, 8))
max((abcd)) # d is max
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 max((1, 2, 5, 8))
# ----> 2 max((abcd)) # d is max
#
# NameError: name 'abcd' is not defined

# %%
sum(x)/len(x)
