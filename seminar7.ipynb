# %%
my_dict = dict()
key = 'ID_32'
value = 'Simon23'
my_dict[key] = value
print(my_dict)
# Out:
# {'ID_32': 'Simon23'}

# %%
score_dict = {}
name = input('Enter students name:')
score = input('Enter the score: ')
score_dict[name] = score
print(score_dict)
# Out:
# {'zhamilya': '345'}

# %%
dict_ = {123: 'Moskow', 234: 'New-York', 532: 'Dublin', 554: 'Neapol', 653: 'Paris', 234: 'Sarov', 564: 'Tokmak'}
print(dict_.keys())
print(dict_.values())
# Out:
# dict_keys([123, 234, 532, 554, 653, 564])
# dict_values(['Moskow', 'Sarov', 'Dublin', 'Neapol', 'Paris', 'Tokmak'])

# %%
dict_[532] = 'Stambul'
print(dict_)
# Out:
# {123: 'Moskow', 234: 'Sarov', 532: 'Stambul', 554: 'Neapol', 653: 'Paris', 564: 'Tokmak'}

# %%
score_dict = {}

input_ = input('Write next or stop: ')
while input_ != 'stop':
    name = input('Enter students name: ')
    score = input('Enter the score: ')
    score_dict[name] = score
    input_ = input('Write next or stop: ')
if input_ != 'next':
    print('"Ввод данных завершен"')
    print(score_dict)
# Out:
# "Ввод данных завершен"
# {'zhami': '90'}
